# %%
from PIL import Image
import os
os.getcwd()
# Out:
# 'C:\\Users\\User\\IMAGE PROCESSING 2MCA'

# %%
# Let us import one image in our Jupyter environment and open that in the notebook itself

image1 = Image.open("cartoon.jpg")

image1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x800 at 0x1630C980340>

# %%
image1.show()

# %%
image1.save("pic1.png")

# %%
# lists all the files and folders in the current working directory
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '1img.jpg',
#  '2img.jpg',
#  'apple.png',
#  'buny.jpg',
#  'canvas.jpg',
#  'cartoon.jpg',
#  'cat_damaged.jpg',
#  'cat_mask.jpg',
#  'contour.ipynb',
#  'convert matrix into image.ipynb',
#  'crop.jpg',
#  'cropping.ipynb',
#  'd.png',
#  'dice.png',
#  'dice1.jpg',
#  'difference.ipynb',
#  'doggy.jpg',
#  'double heart.png',
#  'earth.jpg',
#  'face.jpg',
#  'filtering.ipynb',
#  'fruit.jpg',
#  'globe.jpg',
#  'image',
#  'image manipulation.ipynb',
#  'image10.jpg',
#  'image9.jpg',
#  'images 2.jpg',
#  'images 4.jpg',
#  'images 8.jpg',
#  'images.jpg',
#  'images1.jpg',
#  'images3.jpg',
#  'images5.jpg',
#  'images6.jpg',
#  'images7.jpg',
#  'Image_from_array.png',
#  'imgfrm.jpg',
#  'intensity transformation.ipynb',
#  'inverting to another folder.ipynb',
#  'kanna.jpg',
#  'listing pictures.ipynb',
#  'llogo.jpg',
#  'lo.jpg',
#  'logo.jpg',
#  'mark.jpg',
#  'montage.ipynb',
#  'montage.png',
#  'nature.jpg',
#  'noise.ipynb',
#  'noise.jpg',
#  'npoise.jpg',
#  'op on image.ipynb',
#  'p.jpg',
#  'pdf.png',
#  'pic1.png',
#  'pooki.jpg',
#  'qt.png',
#  'restoration.ipynb',
#  'sample.png',
#  'sampletext.jpg',
#  'sampling.ipynb',
#  'save.jpg',
#  'segmentation.ipynb',
#  'solar.jpg',
#  'sun.jpg',
#  'text removing.ipynb',
#  'Untitled.ipynb',
#  'water.pg.png',
#  'watermark.ipynb',
#  'watermark.jpg']

# %%
for f in os.listdir("."):
    if f.endswith(".jpg"):
        i = Image.open(f)
        fn, fext = os.path.splitext(f)
        print(fn, "&", fext)
# Out:
# 1img & .jpg
# 2img & .jpg
# buny & .jpg
# canvas & .jpg
# cartoon & .jpg
# cat_damaged & .jpg
# cat_mask & .jpg
# crop & .jpg
# dice1 & .jpg
# doggy & .jpg
# earth & .jpg
# face & .jpg
# fruit & .jpg
# globe & .jpg
# image10 & .jpg
# image9 & .jpg
# images 2 & .jpg
# images 4 & .jpg
# images 8 & .jpg
# images & .jpg
# images1 & .jpg
# images3 & .jpg
# images5 & .jpg
# images6 & .jpg
# images7 & .jpg
# imgfrm & .jpg
# kanna & .jpg
# llogo & .jpg
# lo & .jpg
# logo & .jpg
# mark & .jpg
# nature & .jpg
# noise & .jpg
# npoise & .jpg
# p & .jpg
# pooki & .jpg
# sampletext & .jpg
# save & .jpg
# solar & .jpg
# sun & .jpg
# watermark & .jpg

# %%
#Looping over the image files
for f in os.listdir("."):
    if f.endswith(".jpg"):
        print(f)
# Out:
# 1img.jpg
# 2img.jpg
# buny.jpg
# canvas.jpg
# cartoon.jpg
# cat_damaged.jpg
# cat_mask.jpg
# crop.jpg
# dice1.jpg
# doggy.jpg
# earth.jpg
# face.jpg
# fruit.jpg
# globe.jpg
# image10.jpg
# image9.jpg
# images 2.jpg
# images 4.jpg
# images 8.jpg
# images.jpg
# images1.jpg
# images3.jpg
# images5.jpg
# images6.jpg
# images7.jpg
# imgfrm.jpg
# kanna.jpg
# llogo.jpg
# lo.jpg
# logo.jpg
# mark.jpg
# nature.jpg
# noise.jpg
# npoise.jpg
# p.jpg
# pooki.jpg
# sampletext.jpg
# save.jpg
# solar.jpg
# sun.jpg
# watermark.jpg

# %%
# Creating new Directory using OS library
os.mkdir('NewExtnsn')
# Note: If you already have a directory with this name, you will get error.
for f in os.listdir("."):
    if f.endswith(".png"):
        i = Image.open(f)
        fn, fext = os.path.splitext(f)
        i.save("NewExtnsn/{}.pdf".format(fn))

# %%
# Creating new multiple Directories using OS library
os.makedirs('resize//small')
os.makedirs('resize//tiny')
# Note: If you already have a directory with this name, you will get error.
size_small = (600,600) # small images of 600 X 600 pixels
size_tiny = (200,200)  # tiny images of 200 X 200 pixels
for f in os.listdir("."):
    if f.endswith(".png"):
        i = Image.open(f)
        fn, fext = os.path.splitext(f)
        i.thumbnail(size_small)
        i.save("resize/small/{}_small{}".format(fn, fext))
        i.thumbnail(size_tiny)
        i.save("resize/tiny/{}_tiny{}".format(fn, fext))
