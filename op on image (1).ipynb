# %%
import cv2

# %%
image=cv2.imread("images6.jpg")
cv2.imshow("to display image",image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imwrite("C:\pranavya\image9.png",image)
# Out:
# True

# %%
#loading from external drive
image=cv2.imread("C:\pranavya\images (2).jpg")
cv2.imshow("to display image",image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#greyscale
image=cv2.imread("images6.jpg",0)
cv2.imshow("to display image",image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#height and width
from PIL import Image

x="images.jpg"
img=Image.open(x)

width=img.width
height=img.height

print("The height of the image is",height)
print("The weight of the image is",width)
# Out:
# The height of the image is 225
# The weight of the image is 225

# %%
#no of cannels from color-image

import numpy

img=cv2.imread("images1.jpg")
print("No of channels is:"+str(img.ndim))
print("No of channels is:",img.shape)
cv2.imshow("channel",img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# No of channels is:3
# No of channels is: (225, 225, 3)

# %%
#Resize image

from PIL import Image
filepath="images7.jpg"
im=Image.open(filepath)
new_im=im.resize((400,400))
new_im
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x28508DA9FA0>

# %%
#no of cannels from greayscale image

import numpy

img=cv2.imread("images1.jpg",0)
print("No of channels is:"+str(img.ndim))
print("No of channels is:",img.shape)
cv2.imshow("channel",img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# No of channels is:2
# No of channels is: (225, 225)

# %%
#matrix repsresentation of image

import matplotlib.image as image
img=image.imread("image10.jpg")
print("The shape of the image is",img.shape)
print("The array of image is")
print(img)
# Out:
# The shape of the image is (176, 287, 3)
# The array of image is
# [[[ 26  92 170]
#   [ 25  91 169]
#   [ 25  91 169]
#   ...
#   [ 19  97 171]
#   [ 19  97 171]
#   [ 19  97 171]]
#
#  [[ 25  91 169]
#   [ 25  91 169]
#   [ 24  90 168]
#   ...
#   [ 19  97 171]
#   [ 19  97 171]
#   [ 19  97 171]]
#
#  [[ 24  90 168]
#   [ 24  90 168]
#   [ 23  89 167]
#   ...
#   [ 19  97 171]
#   [ 19  97 171]
#   [ 19  97 171]]
#
#  ...
#
#  [[253 254 255]
#   [253 254 255]
#   [253 254 255]
#   ...
#   [254 254 255]
#   [255 253 255]
#   [255 253 255]]
#
#  [[251 255 255]
#   [251 255 255]
#   [251 255 255]
#   ...
#   [254 253 255]
#   [254 253 255]
#   [255 252 255]]
#
#  [[251 255 255]
#   [251 255 255]
#   [251 255 255]
#   ...
#   [253 253 255]
#   [254 252 255]
#   [254 252 255]]]

# %%
#binary image

import cv2
img=cv2.imread("images 2.jpg")
ret,bw_img=cv2.threshold(img,127,255,cv2.THRESH_BINARY)

#converting to its binary form
bw=cv2.threshold(img,127,255,cv2.THRESH_BINARY)

cv2.imshow("BINARY",bw_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
img=cv2.imread("images7.jpg")
B,G,R=cv2.split(img)
print(B)
print(G)
print(R)
# Out:
# [[220 220 219 ... 196 194 176]
#  [220 220 219 ... 199 197 170]
#  [220 220 219 ... 201 197 164]
#  ...
#  [159 159 159 ... 125 126 126]
#  [157 157 157 ... 123 124 124]
#  [157 157 157 ... 123 124 124]]
# [[226 226 225 ... 206 204 186]
#  [226 226 225 ... 209 207 180]
#  [226 226 225 ... 211 207 174]
#  ...
#  [169 169 169 ... 135 136 136]
#  [169 169 169 ... 133 134 134]
#  [169 169 169 ... 133 134 134]]
# [[233 233 232 ... 213 211 193]
#  [233 233 232 ... 216 214 187]
#  [233 233 232 ... 218 214 181]
#  ...
#  [176 176 176 ... 142 143 143]
#  [173 173 173 ... 140 141 141]
#  [173 173 173 ... 140 141 141]]

# %%
cv2.imshow("BLUE",B)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imshow("RED",R)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img=cv2.imread("images 2.jpg")
cv2.imshow("GREEN",G)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#Aspect ratio

img=cv2.imread("images 2.jpg")
new_im=img.resize((400,200))
ar=1*(img.shape[1]/img.shape[0])
print("asepect ratio")
print(ar)
# Out:
# asepect ratio
# 0.5

# %%
#different color spaces
import cv2
img=cv2.imread("image10.jpg")
grey=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
hsv=cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
lab=cv2.cvtColor(img,cv2.COLOR_BGR2LAB)
hls=cv2.cvtColor(img,cv2.COLOR_BGR2HLS)
yuv=cv2.cvtColor(img,cv2.COLOR_BGR2YUV)

cv2.imshow("GREY",grey)
cv2.imshow("HSV",hsv)
cv2.imshow("LAB",lab)
cv2.imshow("HLS",hls)
cv2.imshow("YUV",yuv)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#miror image
from PIL import Image
filepath="image9.jpg"
img=Image.open(filepath)
hori_flippedImage=img.transpose(Image.FLIP_LEFT_RIGHT)
img.show()
hori_flippedImage.show()

#vertical
vert_flippedImage=img.transpose(Image.FLIP_TOP_BOTTOM)
vert_flippedImage.show()

# %%
import cv2
img1=cv2.imread("buny.jpg")
img2=cv2.imread("doggy.jpg")
sum=img1+img2
sub=img1-img2
mul=img1*img2
div=img1/img2
cv2.imshow("sum:",sum)
cv2.imshow("sub:",sub)
cv2.imshow("mul:",mul)
cv2.imshow("div:",div)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_1188/890987873.py:7: RuntimeWarning: divide by zero encountered in true_divide
#   div=img1/img2
