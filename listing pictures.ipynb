# %%
# listing png images
import os
from os import listdir

# get the path/directory
folder_dir = "C:/pranavya"
for images in os.listdir(folder_dir):

	# check if the image ends with png
    if (images.endswith(".png")):
        print(images)
# Out:
# image9.png
# images.png
# qt.png
# sample.png
# water.pg.png

# %%
# listing all images
import os
from os import listdir

# get the path/directory
folder_dir = "C:/pranavya"
for images in os.listdir(folder_dir):
        print(images)
# Out:
# 1img.jpg
# 2img.jpg
# buny.jpg
# canvas.jpg
# cartoon.jpg
# cat_damaged.jpg
# cat_mask.jpg
# crop.jpg
# doggy.jpg
# download (1).jpg
# download.jpg
# earth.jpg
# globe.jpg
# image9.png
# images (1).jpg
# images (2).jpg
# images (3).jpg
# images (4).jpg
# images (5).jpg
# images (6).jpg
# images (7).jpg
# images.jpg
# images.png
# kanna.jpg
# maek.jpg
# mark.jpg
# nature.jpg
# npoise.jpg
# p.jpg
# qt.png
# quote.jpg
# sample.png
# sampletext.jpg
# solar.jpg
# sun.jpg
# sun2.jpg
# water.pg.png
# watermark.jpg

# %%
#dipaly all images in folder
#import necessary packages 
import cv2 
import os 
import glob 
import matplotlib.pyplot as plt 
# %matplotlib inline 
 
#Set the path where images are stored 
img_dir = "C:/pranavya" # Enter Directory of all images  
data_path = os.path.join(img_dir,'*') 
files = glob.glob(data_path) 
data = [] 
for f1 in files: 
    img = cv2.imread(f1,0) 
    data.append(img) 
    plt.figure() 
    plt.imshow(img)
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_7896/1775118648.py:17: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
